# %%
# Uncomment and run if running into errors when trying to train the model

import os
os.environ["TORCHDYNAMO_DISABLE"] = "1"
os.environ["UNSLOTH_COMPILE_DISABLE"] = "1"
os.environ["TORCHDYNAMO_VERBOSE"] = "1"

# %%
# Force reinstall the specified version (4.41.1) of the transformers library
# !pip install -U --force-reinstall transformers==4.41.1

# Import the library
import transformers

# Print out the current version to confirm the installation
print(transformers.__version__)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 117.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.8/558.8 kB 46.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 111.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 53.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 kB 60.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 34.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 28.2 MB/s eta 0:00:00
# ...

# %%
# Run if the code block to train the model is not working and showing errors.
# !pip install -U transformers accelerate peft bitsandbytes datasets

# !pip install vllm
# !pip install -U transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 125.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.9/503.9 kB 39.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 30.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.8 MB/s eta 0:00:00
# ...

# %%
# Access your hugging face API
from huggingface_hub import login
login("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")

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
##Added tokenizer and model loading code for Phi-2 using Hugging Face Transformers
model_id = "microsoft/phi-2"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, trust_remote_code=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
# Access your weights and biases API
import wandb

# Direct login with your API key
wandb.login(key="20884256a1b64e4ded94f28d47768fe9e2ef641b")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: malcolmfelix32 (malcolmfelix32-prairie-view-a-m-univeristy-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# Creates a new project to track experiemnts and fine-tuning process
run = wandb.init(
    project='phi_humour_biasrhetoric3',
    job_type="training",
    anonymous="allow"
)
# Out:
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20250805_021849-2qaont81</code>
# Syncing run <strong><a href='https://wandb.ai/malcolmfelix32-prairie-view-a-m-univeristy-/phi_humour_biasrhetoric3/runs/2qaont81?apiKey=20884256a1b64e4ded94f28d47768fe9e2ef641b' target="_blank">avid-leaf-2</a></strong> to <a href='https://wandb.ai/malcolmfelix32-prairie-view-a-m-univeristy-/phi_humour_biasrhetoric3?apiKey=20884256a1b64e4ded94f28d47768fe9e2ef641b' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/malcolmfelix32-prairie-view-a-m-univeristy-/phi_humour_biasrhetoric3?apiKey=20884256a1b64e4ded94f28d47768fe9e2ef641b' target="_blank">https://wandb.ai/malcolmfelix32-prairie-view-a-m-univeristy-/phi_humour_biasrhetoric3?apiKey=20884256a1b64e4ded94f28d47768fe9e2ef641b</a>
# ...

# %%
from huggingface_hub import notebook_login
notebook_login()
#Logs in to hugging face

# %%
# Import necessary components from HuggingFace Transformers and PEFT (Parameter-Efficient Fine-Tuning)
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model, TaskType
import torch

# Define the model to use (Phi-2 by Microsoft)
model_id = "microsoft/phi-2"

# Load the tokenizer from the model ID
tokenizer = AutoTokenizer.from_pretrained(model_id)
tokenizer.pad_token = tokenizer.eos_token  # Set padding token to EOS token for causal LM

# Load the base model with:
# - 4-bit quantization (saves memory)
# - Float16 data type (for efficient computation)
# - Automatic device placement (CPU/GPU)
# - Trust remote code if needed for custom model behavior
base_model = AutoModelForCausalLM.from_pretrained(
    model_id,
    load_in_4bit=True,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True
)

# Prepare the model for 4-bit training with PEFT
base_model = prepare_model_for_kbit_training(base_model)

# Configure LoRA (Low-Rank Adaptation) for parameter-efficient fine-tuning
lora_config = LoraConfig(
    r=8,  # LoRA rank
    lora_alpha=32,  # Scaling factor
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj"],  # Target transformer modules
    lora_dropout=0.1,  # Dropout for LoRA layers
    bias="none",  # Don't fine-tune existing bias terms
    task_type=TaskType.CAUSAL_LM  # Task is causal language modeling
)

# Apply LoRA configuration to the base model
model = get_peft_model(base_model, lora_config)

# Print how many parameters are being fine-tuned
model.print_trainable_parameters()
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# trainable params: 3,932,160 || all params: 2,783,616,000 || trainable%: 0.1413

# %%
from google.colab import drive
drive.mount('/content/gdrive')
#Mounts to google drice
# Out:
# Mounted at /content/gdrive

# %%
import os
os.path.exists('/content/gdrive/MyDrive/data/train.csv')
##Checks if the csv path is correct
# Out:
# True

# %%
import os
os.path.exists('/content/gdrive/MyDrive/data/validation.csv')
# Out:
# True

# %%
from datasets import load_dataset
##Loaded dataset and formatted for causal language modeling with classification prompt

dataset = load_dataset("csv", data_files={
    "train": "/content/gdrive/MyDrive/data/train.csv",
    "validation": "/content/gdrive/MyDrive/data/validation.csv"
})

def format_for_clm(example):
    instruction = (
        "Classify the rhetoric label group of the text into ONE of the following labels:\n"
        "wordplay","not a joke", "irony", "dark humor", "satire", "cultural reference", "vulgarity", "hyperbole", "misunderstanding", "other", "puns", "none", "sarcasm", "self-deprecation.\n"
        "Return ONLY the label.\n\n"
    )
    text = f"{instruction}Joke: {example['joke']}\n\nrhetoric: {example['rhetoric']}"
    return {
        "text": text,
        "label": example["rhetoric"]  # needed for evaluation
    }

formatted = dataset.map(format_for_clm)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# ...
# Map:   0%|          | 0/662 [00:00<?, ? examples/s]

# %%
formatted["validation"][100]
#loads example
# Out:
# {'joke': ' If a guy remembers the color of your eyes after the first date, chances are... you have small boobs. ',
#  'label': 'satire',
#  'target': 'body image',
#  'rhetoric': 'satire',
#  'text': "('Classify the rhetoric label group of the text into ONE of the following labels:\\nwordplay', 'not a joke', 'irony', 'dark humor', 'satire', 'cultural reference', 'vulgarity', 'hyperbole', 'misunderstanding', 'other', 'puns', 'none', 'sarcasm', 'self-deprecation.\\nReturn ONLY the label.\\n\\n')Joke:  If a guy remembers the color of your eyes after the first date, chances are... you have small boobs. \n\nrhetoric: satire"}

# %%
# Define a tokenization function for each example in the dataset
def tokenize(example):
    # Tokenize the 'text' field with padding and truncation
    encodings = tokenizer(
        example["text"],               # Input text to tokenize
        padding="max_length",          # Pad sequences to the max_length
        truncation=True,               # Truncate sequences longer than max_length
        max_length=512                 # Set maximum sequence length
    )

    # Labels = input_ids (for causal language modeling)
    encodings["labels"] = encodings["input_ids"].copy()

    return encodings

# Apply the tokenization function to the entire dataset in batches
tokenized = formatted.map(tokenize, batched=True)
# Out:
# ...
# Map:   0%|          | 0/662 [00:00<?, ? examples/s]

# %%
tokenizer.pad_token = tokenizer.eos_token
##Set tokenizer pad token to EOS token to prevent padding-related issues during training

# %%
tokenized["train"][0].keys()
##Verified tokenized output keys to inspect tokenization structure
# Out:
# dict_keys(['joke', 'label', 'target', 'rhetoric', 'text', 'input_ids', 'attention_mask', 'labels'])

# %%
#Initialized data collator for causal language modeling with MLM disabled

from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

# %%
tokenized_clean = tokenized.remove_columns(["joke", "label", "target", "rhetoric", "text"])
##Removes labels for training

# %%
#Verified cleaned validation sample to confirm necessary model input keys are present
tokenized_clean["validation"][0].keys()
# Out:
# dict_keys(['input_ids', 'attention_mask', 'labels'])

# %%
# Configured Trainer with training arguments and initialized training pipeline for Phi-2 with LoRA

from transformers import TrainingArguments, Trainer

# Define the training configuration for the model
training_args = TrainingArguments(
    output_dir="./phi2-lora-label2",           # Directory to save checkpoints and model outputs
    per_device_train_batch_size=4,              # Batch size per device for training
    per_device_eval_batch_size=4,               # Batch size per device for evaluation
    num_train_epochs=3,                         # Total number of training epochs
    logging_steps=20,                           # How often to log during training
    save_strategy="epoch",                      # Save model checkpoint at the end of every epoch
    eval_strategy="epoch",                      # Evaluate model performance at the end of every epoch
    fp16=True,                                  # Use 16-bit floating point precision for faster training
    save_total_limit=1,                         # Only keep 1 checkpoint to save disk space
    report_to=None,                             # Disable reporting to external tools (like wandb)
    push_to_hub=True,                           # Push the trained model to the Hugging Face Hub
    hub_model_id="3elix/phi2_humor_bias2",      # Name of the model repo on the Hub
)

# Create a Trainer instance that handles the training and evaluation loop
trainer = Trainer(
    model=model,                                # The LoRA-adapted Phi-2 model
    args=training_args,                         # Training arguments defined above
    train_dataset=tokenized_clean["train"],     # Training data (already tokenized and cleaned)
    eval_dataset=tokenized_clean["validation"], # Validation data for evaluation
    tokenizer=tokenizer,                        # Tokenizer used to process text inputs
    data_collator=data_collator                 # Data collator handles padding and batching
)

# Start training the model
trainer.train()
# Out:
# /tmp/ipython-input-1378724232.py:18: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# ...

# %%
trainer.push_to_hub()
#Uploads to github
# Out:
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...ra-labelrhetoric3/training_args.bin: 100%|##########| 5.84kB / 5.84kB
#   ...ents.1754360391.92ae3483a9c2.5665.0: 100%|##########| 25.7kB / 25.7kB
#   ...rhetoric3/adapter_model.safetensors: 100%|##########| 15.8MB / 15.8MB
# CommitInfo(commit_url='https://huggingface.co/3elix/phi_humour_biasrhetoric3/commit/9873e166668f78d2b7fd9f56d84c97190188282f', commit_message='End of training', commit_description='', oid='9873e166668f78d2b7fd9f56d84c97190188282f', pr_url=None, repo_url=RepoUrl('https://huggingface.co/3elix/phi_humour_biasrhetoric3', endpoint='https://huggingface.co', repo_type='model', repo_id='3elix/phi_humour_biasrhetoric3'), pr_revision=None, pr_num=None)

# %%
from sklearn.metrics import classification_report
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
from tqdm import tqdm
import torch
import re


valid_labels = [
    "wordplay", "irony", "dark humor", "satire", "cultural reference",
    "vulgarity", "hyperbole", "misunderstanding", "other",
    "puns", "none", "not a joke", "sarcasm", "self-deprecation"
]


def clean_prediction(pred):
    pred = pred.lower().strip()
    pred = re.sub(r'\s+', ' ', pred)  # remove extra spaces
    parts = [p.strip() for p in pred.split("/") if p.strip()]
    deduped = list(dict.fromkeys(parts))  # remove duplicates
    return "/".join(deduped)

def map_to_valid_label(pred):
    pred = pred.lower()
    for label in valid_labels:
        if label in pred:
            return label
    return "other"

base_model = AutoModelForCausalLM.from_pretrained("microsoft/phi-2")
tokenizer = AutoTokenizer.from_pretrained("3elix/phi_humour_biasrhetoric3")
model = PeftModel.from_pretrained(base_model, "3elix/phi_humour_biasrhetoric3")
model = model.to("cuda" if torch.cuda.is_available() else "cpu")


true_labels = []
predicted_labels = []

# Replace `formatted` with your actual validation dataset variable
for example in tqdm(formatted["validation"]):
    true_target = example.get("rhetoric")
    joke_text = example.get("joke")

    # Skip missing data
    if true_target is None or joke_text is None:
        continue

    # Instruction prompt for model
    instruction = (
        "Classify the rhetoric label group of the text into ONE of the following labels:\n"
        "wordplay, irony, dark humor, satire, cultural reference, vulgarity, hyperbole, "
        "misunderstanding, other, puns, none, not a joke, sarcasm, self-deprecation.\n"
        "Return ONLY the label as a single word or phrase with no punctuation.\n\n"
    )

    prompt = f"{instruction}Joke: {joke_text}\n\nlabel:"
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    # Generate prediction
    output = model.generate(
        **inputs,
        max_new_tokens=15,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.pad_token_id
    )

    # Decode and clean prediction
    input_len = inputs["input_ids"].shape[1]
    generated_ids = output[0][input_len:]
    prediction = tokenizer.decode(generated_ids, skip_special_tokens=True).strip()
    prediction = clean_prediction(prediction)
    prediction = map_to_valid_label(prediction)

    predicted_labels.append(prediction)
    true_labels.append(true_target.strip().lower())


print(classification_report(true_labels, predicted_labels, labels=valid_labels))
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/876 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/15.8M [00:00<?, ?B/s]
# 100%|██████████| 662/662 [10:39<00:00,  1.04it/s]
#                     precision    recall  f1-score   support
#
#           wordplay       0.33      0.89      0.48       163
#              irony       0.00      0.00      0.00        18
#         dark humor       0.19      0.11      0.14        73
#             satire       0.00      0.00      0.00        81
# cultural reference       0.00      0.00      0.00        41
#          vulgarity       0.44      0.38      0.41        52
# ...

# %%
from sklearn.metrics import classification_report
import pandas as pd
import json

report_dict = classification_report(true_labels, predicted_labels, output_dict=True)

#Save as CSV
pd.DataFrame(report_dict).transpose().to_csv("classification_reportphi.csv")

# %%
# !ls -lh classification_reportphi.*
#makes sure that the report is in the right directory
# Out:
# -rw-r--r-- 1 root root 647 Aug  4 04:25 classification_reportphi.csv

# %%
from google.colab import files
files.download("classification_reportphi.csv")
#downloads report
